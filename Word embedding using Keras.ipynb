# %%
from tensorflow.keras.preprocessing.text import one_hot # library to one hot encode these sentences

# %%
sentences=sent=[  'the glass of milk',
     'the glass of juice',
     'the cup of tea',
    'I am a good boy',
     'I am a good developer',
     'understand the meaning of words',
     'your videos are good',]

# %%
sentences
# Out:
# ['the glass of milk',
#  'the glass of juice',
#  'the cup of tea',
#  'I am a good boy',
#  'I am a good developer',
#  'understand the meaning of words',
#  'your videos are good']

# %%
vocab_size=10000 #vocalbulary dictionary size

# %%
#method 1
onehot_repr=[one_hot(words,vocab_size)for words in sentences] 
print(onehot_repr)
# Out:
# [[6876, 6827, 6239, 3398], [6876, 6827, 6239, 4489], [6876, 1849, 6239, 2547], [64, 8681, 4831, 6206, 475], [64, 8681, 4831, 6206, 6922], [8287, 6876, 4805, 6239, 5748], [154, 9304, 1059, 6206]]

# %%
#method 2
onehot_repr2=[]
for sentence in sentences:
    encoded_sentence = one_hot(sentence, vocab_size)
    onehot_repr2.append(encoded_sentence)

# %%
print(onehot_repr2)
# Out:
# [[6876, 6827, 6239, 3398], [6876, 6827, 6239, 4489], [6876, 1849, 6239, 2547], [64, 8681, 4831, 6206, 475], [64, 8681, 4831, 6206, 6922], [8287, 6876, 4805, 6239, 5748], [154, 9304, 1059, 6206]]

# %%
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential

# %%
import numpy as np

# %%
sent_length=8
embedded_docs=pad_sequences(onehot_repr,padding='pre',maxlen=sent_length)
print(embedded_docs)
# Out:
# [[   0    0    0    0 6876 6827 6239 3398]
#  [   0    0    0    0 6876 6827 6239 4489]
#  [   0    0    0    0 6876 1849 6239 2547]
#  [   0    0    0   64 8681 4831 6206  475]
#  [   0    0    0   64 8681 4831 6206 6922]
#  [   0    0    0 8287 6876 4805 6239 5748]
#  [   0    0    0    0  154 9304 1059 6206]]

# %%
dim=10

# %%
model=Sequential()
model.add(Embedding(vocab_size,dim,input_length=sent_length))
model.compile('adam','mse')

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding_2 (Embedding)     (None, 8, 10)             100000
#
# ...
# Total params: 100,000
# Trainable params: 100,000
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.predict(embedded_docs) #Each sentence is one hot encoded using dim(10) features
# Out:
# 1/1 [==============================] - 0s 84ms/step
# 2024-07-30 18:09:56.616711: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# array([[[-0.04012595,  0.00391046, -0.03334867, -0.01932571,
#           0.01427511,  0.02332201, -0.00609485,  0.03578841,
#          -0.03428417, -0.04016785],
#         [-0.04012595,  0.00391046, -0.03334867, -0.01932571,
#           0.01427511,  0.02332201, -0.00609485,  0.03578841,
#          -0.03428417, -0.04016785],
#         [-0.04012595,  0.00391046, -0.03334867, -0.01932571,
#           0.01427511,  0.02332201, -0.00609485,  0.03578841,
#          -0.03428417, -0.04016785],
#         [-0.04012595,  0.00391046, -0.03334867, -0.01932571,
#           0.01427511,  0.02332201, -0.00609485,  0.03578841,
#          -0.03428417, -0.04016785],
#         [ 0.00222214,  0.00763335,  0.04987539, -0.0290463 ,
#           0.01832295,  0.02716095,  0.04074855, -0.00492972,
#           0.03575378,  0.00832295],
# ...
